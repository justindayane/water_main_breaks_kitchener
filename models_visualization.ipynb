# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

compare_cols = ["Model","Accuracy", "F1", "Recall", "Precision"]
metrics = pd.read_csv("//Users//justindayane//Documents//Spring_24//Supervised_Research//Neh//metrics.csv")
new_metrics = metrics[compare_cols]
reported = [
("Random forest", 0.973, 0.804, 0.723, 0.906),
("Logistic Regression", 0.969, 0.774, 0.683, 0.893),
("Decision Tree", 0.973, 0.80, 0.704, 0.926),
("GNB", 0.961, 0.737, 0.712, 0.764),
("KNN", 0.968, 0.763, 0.67, 0.886)
]
reported = pd.DataFrame(data=reported, columns = compare_cols)

new_metrics = new_metrics.sort_values('Model')
reported = reported.sort_values('Model')

# %%
new_metrics = new_metrics[:-1]
reported

# %%
list(new_metrics['Model'])
# Out:
# ['DecisionTreeClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LogisticRegression',
#  'RandomForestClassifier']

# %%
reported
# Out:
#                  Model  Accuracy     F1  Recall  Precision
# 2        Decision Tree     0.973  0.800   0.704      0.926
# 3                  GNB     0.961  0.737   0.712      0.764
# 4                  KNN     0.968  0.763   0.670      0.886
# 1  Logistic Regression     0.969  0.774   0.683      0.893
# 0        Random forest     0.973  0.804   0.723      0.906

# %%
new_metrics
# Out:
#                     Model  Accuracy        F1    Recall  Precision
# 3  DecisionTreeClassifier  0.986050  0.949868  0.949033   0.950704
# 1              GaussianNB  0.654185  0.425843  0.920914   0.276956
# 5    KNeighborsClassifier  0.976750  0.914645  0.894552   0.935662
# 0      LogisticRegression  0.971855  0.894204  0.854130   0.938224
# 4  RandomForestClassifier  0.988497  0.957848  0.938489   0.978022

# %%
list(reported['Model'])
# Out:
# ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest']

# %%
new_metrics_acc = list(new_metrics['Accuracy'])
reported_acc = list(reported['Accuracy'])

# %%
barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_acc))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
plt.bar(br1, new_metrics_acc, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.bar(br2, reported_acc, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Accuracy', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_acc))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_acc_comp.png")
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %%
new_metrics_rec = list(new_metrics['Recall'])
reported_rec = list(reported['Recall'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_rec))]
br2 = [x + barWidth for x in br1]

plt.bar(br1, new_metrics_rec, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.bar(br2, reported_rec, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Recall', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_rec))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_rec_comp.png")
plt.show()

# %%
new_metrics_pre = list(new_metrics['Precision'])
reported_pre = list(reported['Precision'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_pre))]
br2 = [x + barWidth for x in br1]

plt.bar(br1, new_metrics_pre, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.bar(br2, reported_pre, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Precision', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_pre))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_pre_comp.png")
plt.show()

# %%
new_metrics_f = list(new_metrics['F1'])
reported_f = list(reported['F1'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_f))]
br2 = [x + barWidth for x in br1]

#Trying the confidence interval with random numbers
yer1 = [x + barWidth for x in np.arange(len(new_metrics_f))]
yer2 = [x + barWidth for x in yer1]

plt.bar(br1, new_metrics_f, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.bar(br2, reported_pre, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('F1', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_f))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])


plt.legend()
#plt.savefig("Images/models_f1_comp.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

new_metrics_pre = list(new_metrics['Precision'])
reported_pre = list(reported['Precision'])

barWidth = 0.25
fig = plt.subplots(figsize=(10, 6))

br1 = [x for x in np.arange(len(new_metrics_pre))]
br2 = [x + barWidth for x in br1]

# Compute error bars
new_metrics_pre_errors = [0.05 for x in range(len(new_metrics_pre))]  # Example values, replace with actual error values
reported_pre_errors = [0.05 for x in range(len(reported_pre))]        # Example values, replace with actual error values

# Plot bars with error bars
plt.bar(br1, new_metrics_pre, color='red', width=barWidth, edgecolor='black', label='Ours')
plt.errorbar(br1, new_metrics_pre, yerr=new_metrics_pre_errors, fmt='none', color='black')

plt.bar(br2, reported_pre, color='green', width=barWidth, edgecolor='black', label='Omar et al')
plt.errorbar(br2, reported_pre, yerr=reported_pre_errors, fmt='none', color='black')

plt.xlabel('Model', fontweight='bold', fontsize=15)
plt.ylabel('Precision', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(new_metrics_pre))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
# plt.savefig("Images/models_pre_comp.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

new_metrics_pre = list(new_metrics['Precision'])
reported_pre = list(reported['Precision'])

# Confidence level
confidence_level = 0.95

# Calculate confidence intervals
new_metrics_pre_mean = np.mean(new_metrics_pre)
new_metrics_pre_std = np.std(new_metrics_pre)
n_new = len(new_metrics_pre)
new_metrics_pre_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (new_metrics_pre_std / np.sqrt(n_new))

reported_pre_mean = np.mean(reported_pre)
reported_pre_std = np.std(reported_pre)
n_reported = len(reported_pre)
reported_pre_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (reported_pre_std / np.sqrt(n_reported))

# Plot
barWidth = 0.25
fig, ax = plt.subplots(figsize=(10, 6))

br1 = [x for x in np.arange(len(new_metrics_pre))]
br2 = [x + barWidth for x in br1]

plt.bar(br1, new_metrics_pre, color='red', width=barWidth, edgecolor='black', label='Ours')
plt.errorbar(br1, new_metrics_pre, yerr=new_metrics_pre_margin_error, fmt='none', ecolor='black')

plt.bar(br2, reported_pre, color='green', width=barWidth, edgecolor='black', label='Omar et al')
plt.errorbar(br2, reported_pre, yerr=reported_pre_margin_error, fmt='none', ecolor='black')

plt.xlabel('Model', fontweight='bold', fontsize=15)
plt.ylabel('Precision', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(new_metrics_pre))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
plt.show()

# %%
import numpy as np  # Importing a library for numerical operations
import matplotlib.pyplot as plt  # Importing a library for plotting
from scipy import stats  # Importing a library for statistical functions

# Sample data
new_metrics_pre = [0.85, 0.75, 0.80, 0.82, 0.78]  # Example precision values for 'Ours'
reported_pre = [0.82, 0.78, 0.79, 0.80, 0.76]  # Example precision values for 'Omar et al'

# Confidence level
confidence_level = 0.95  # The level of confidence we want to have in our interval (here, 95%)

# Calculate confidence intervals for 'Ours' model
new_metrics_pre_mean = np.mean(new_metrics_pre)  # Calculate the average (mean) precision
new_metrics_pre_std = np.std(new_metrics_pre)  # Calculate the standard deviation of the precision values
n_new = len(new_metrics_pre)  # Count how many precision values we have
# Calculate the margin of error for the mean precision using a statistical formula
new_metrics_pre_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (new_metrics_pre_std / np.sqrt(n_new))

# Calculate confidence intervals for 'Omar et al' model (similar steps as above)
reported_pre_mean = np.mean(reported_pre)
reported_pre_std = np.std(reported_pre)
n_reported = len(reported_pre)
reported_pre_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (reported_pre_std / np.sqrt(n_reported))

# Plot
barWidth = 0.25  # Set the width of the bars in the bar chart

# Create a figure and axis object for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create arrays for the x-coordinates of the bars for each model
br1 = [x for x in np.arange(len(new_metrics_pre))]  # For 'Ours' model
br2 = [x + barWidth for x in br1]  # For 'Omar et al' model

# Plot bars for 'Ours' model and add error bars corresponding to the confidence interval
plt.bar(br1, new_metrics_pre, color='red', width=barWidth, edgecolor='black', label='Ours')
plt.errorbar(br1, new_metrics_pre, yerr=new_metrics_pre_margin_error, fmt='none', ecolor='black')

# Plot bars for 'Omar et al' model and add error bars corresponding to the confidence interval
plt.bar(br2, reported_pre, color='green', width=barWidth, edgecolor='black', label='Omar et al')
plt.errorbar(br2, reported_pre, yerr=reported_pre_margin_error, fmt='none', ecolor='black')

# Label the x-axis and y-axis
plt.xlabel('Model', fontweight='bold', fontsize=15)
plt.ylabel('Precision', fontweight='bold', fontsize=15)

# Set custom labels for the x-axis ticks
plt.xticks([r + barWidth for r in range(len(new_metrics_pre))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ## Trying out the confidence interval on each metric

# %%
# F1 Score with confidence interval of 95%
new_metrics_f = list(new_metrics['F1'])
reported_f = list(reported['F1'])

# Confidence level
confidence_level = 0.95

# Calculate confidence intervals
new_metrics_f_mean = np.mean(new_metrics_f)
new_metrics_f_std = np.std(new_metrics_f)
n_new = len(new_metrics_f)
new_metrics_f_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (new_metrics_f_std / np.sqrt(n_new))

reported_f_mean = np.mean(reported_f)
reported_f_std = np.std(reported_f)
n_reported = len(reported_f)
reported_f_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (reported_f_std / np.sqrt(n_reported))



barWidth = 0.25
fig = plt.subplots(figsize = (10,6))


br1 = [x for x in np.arange(len(new_metrics_f))]
br2 = [x + barWidth for x in br1]

#Trying the confidence interval with random numbers
yer1 = [x + barWidth for x in np.arange(len(new_metrics_f))]
yer2 = [x + barWidth for x in yer1]

plt.bar(br1, new_metrics_f, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.errorbar(br1, new_metrics_f, yerr=new_metrics_f_margin_error, fmt='none', ecolor='black')

plt.bar(br2, reported_f, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')
plt.errorbar(br2, reported_f, yerr=reported_f_margin_error, fmt='none', ecolor='black')


plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('F1', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_f))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])


plt.legend()
#plt.savefig("Images/models_f1_comp.png")
plt.show()

# %%
#Recall using 95% Confidence Interval
new_metrics_rec = list(new_metrics['Recall'])
reported_rec = list(reported['Recall'])

# Confidence level
confidence_level = 0.95

# Calculate confidence intervals
new_metrics_rec_mean = np.mean(new_metrics_rec)
new_metrics_rec_std = np.std(new_metrics_rec)
n_new = len(new_metrics_rec)
new_metrics_rec_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (new_metrics_rec_std / np.sqrt(n_new))

reported_rec_mean = np.mean(reported_rec)
reported_rec_std = np.std(reported_rec)
n_reported = len(reported_rec)
reported_rec_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (reported_rec_std / np.sqrt(n_reported))



barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_rec))]
br2 = [x + barWidth for x in br1]

plt.bar(br1, new_metrics_rec, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.errorbar(br1, new_metrics_rec, yerr=new_metrics_rec_margin_error, fmt='none', ecolor='black')

plt.bar(br2, reported_rec, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')
plt.errorbar(br2, reported_rec, yerr=reported_rec_margin_error, fmt='none', ecolor='black')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Recall', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_rec))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_rec_comp.png")
plt.show()

# %%
#Accuracy using 95% Confidence Interval
new_metrics_acc = list(new_metrics['Accuracy'])
reported_acc = list(reported['Accuracy'])

# Confidence level
confidence_level = 0.95

# Calculate confidence intervals
new_metrics_acc_mean = np.mean(new_metrics_acc)
new_metrics_acc_std = np.std(new_metrics_acc)
n_new = len(new_metrics_acc)
new_metrics_acc_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (new_metrics_acc_std / np.sqrt(n_new))

reported_acc_mean = np.mean(reported_acc)
reported_acc_std = np.std(reported_acc)
n_reported = len(reported_acc)
reported_acc_margin_error = stats.norm.ppf(1 - (1 - confidence_level) / 2) * (reported_acc_std / np.sqrt(n_reported))


barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_acc))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
plt.bar(br1, new_metrics_acc, color ='red', width = barWidth, edgecolor ='black', label ='Ours')
plt.errorbar(br1, new_metrics_acc, yerr=new_metrics_acc_margin_error, fmt='none', ecolor='black')

plt.bar(br2, reported_acc, color ='green', width = barWidth, edgecolor ='black', label ='Omar et al')
plt.errorbar(br2, reported_acc, yerr=reported_acc_margin_error, fmt='none', ecolor='black')



plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Accuracy', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_acc))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_acc_comp.png")
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %% [markdown]
# ## New Try

# %% [markdown]
# ### But first lets Practice

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

N = 5
men_means = (54.74, 42.35, 67.37, 58.24, 30.25)
men_std= (4, 3, 4, 1, 5)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

# add some text for labels, title and axes ticks
plt.ylabel('Scores')
plt.xlabel('Velocity')
plt.title('Scores by Velocity')

red_patch = mpatches.Patch(color='red', label='Men')
plt.legend(handles=[red_patch])


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
       height = rect.get_height()
       ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
       ha='center', va='bottom')
autolabel(rects1)
plt.show()
# Out:
# [0 1 2 3 4]

# %% [markdown]
# ### Let the Work Begin !!!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

compare_cols = ["Model","Accuracy", "F1", "Recall", "Precision", "AUC"]
std_cols = ["Model", "Accuracy_std", "F1_std", "Recall_std", "Precision_std", "AUC_std"]
our_metrics = pd.read_csv("//Users//justindayane//Documents//Spring_24//Supervised_Research//Neh//our_metrics.csv")

new_metrics = our_metrics[compare_cols]
new_std = our_metrics[std_cols]

omar_replicated_metrics = pd.read_csv("//Users//justindayane//Documents//Spring_24//Supervised_Research//Neh//omar_replicated_metrics.csv")
reported = omar_replicated_metrics[compare_cols]
reported_std = omar_replicated_metrics[std_cols]

col_for_reported = ["Model", "Accuracy", "F1", "Recall", "Precision", "AUC", "Accuracy_std"]
reported_original = [
("Random forest", 0.973, 0.804, 0.723, 0.906, 0.814, 0.036),
("Logistic Regression", 0.969, 0.774, 0.683, 0.893, 0.788, 0.004),
("Decision Tree", 0.973, 0.80, 0.704, 0.926, 0.815, 0.005),
("GNB", 0.961, 0.737, 0.712, 0.764, 0.738, 0.004),
("KNN", 0.968, 0.763, 0.67, 0.886, 0.778, 0.004),
]

reported_original = pd.DataFrame(data=reported_original, columns = col_for_reported)


new_metrics = new_metrics.sort_values('Model')
reported = reported.sort_values('Model')
reported_original = reported_original.sort_values('Model')

display(new_metrics)
# Out:
#                     Model  Accuracy        F1    Recall  Precision       AUC
# 0  DecisionTreeClassifier  0.977788  0.924601  0.933456   0.920049  0.961342
# 1              GaussianNB  0.622963  0.400229  0.875516   0.273988  0.890996
# 2    KNeighborsClassifier  0.961939  0.859424  0.834279   0.888264  0.908719
# 3      LogisticRegression  0.973567  0.903938  0.870338   0.943249  0.987459
# 4  RandomForestClassifier  0.984519  0.945451  0.934305   0.958060  0.989823
# 5                     SVC  0.982010  0.935933  0.917132   0.956106  0.980013

# %% [markdown]
# **Let's focus on Accuracy here first

# %%
new_metrics = new_metrics[:-1]
new_std = new_std[:-1]
new_metrics_acc = list(new_metrics['Accuracy'])
reported_acc = list(reported['Accuracy'])
reported_original_acc = list(reported_original['Accuracy'])

#The Standard Deviations
new_metrics_acc_std = list(new_std['Accuracy_std'])
reported_acc_std = list(reported_std['Accuracy_std'])
reported_original_acc_std = list(reported_original['Accuracy_std'])
display(reported_acc)
## figure out how to add the std to the original reported metrics reported_original_acc_std =
# Out:
# [0.9847639046410566,
#  0.8904116275326679,
#  0.8721788522939524,
#  0.8577373025052497,
#  0.9856819347280084]

# %%
barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_acc))]
print(br1)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
print(br2)
plt.bar(br1, new_metrics_acc, color = 'red', width = barWidth, edgecolor = 'black', label = 'Ours')
plt.errorbar(br1, new_metrics_acc, yerr=new_metrics_acc_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br2, reported_acc, color = 'green', width = barWidth, edgecolor = 'black', label = 'Omar et al')
plt.errorbar(br2, reported_acc, yerr=reported_acc_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br3, reported_original_acc, color = 'blue', width = barWidth, edgecolor = 'black', label = 'Reported Omar et al')
plt.errorbar(br3, reported_original_acc, yerr=reported_acc_std, fmt='none', capsize = 5, ecolor='black')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Accuracy', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_acc))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
#plt.savefig("Images/models_acc_comp.png")
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %% [markdown]
# **Moving on to Precision

# %%
new_metrics_pre = list(new_metrics['Precision'])
reported_pre = list(reported['Precision'])
reported_original_pre = list(reported_original['Precision'])

#The Standard Deviations
new_metrics_pre_std = list(new_std['Precision_std'])
reported_pre_std = list(reported_std['Precision_std'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_pre))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
br3 = [x + barWidth for x in br2]

plt.bar(br1, new_metrics_pre, color = 'red', width = barWidth, edgecolor = 'black', label = 'Ours')
plt.errorbar(br1, new_metrics_pre, yerr=new_metrics_pre_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br2, reported_pre, color = 'green', width = barWidth, edgecolor = 'black', label = 'Omar et al')
plt.errorbar(br2, reported_pre, yerr=reported_pre_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br3, reported_original_pre, color = 'blue', width = barWidth, edgecolor = 'black', label = 'Reported Omar et al')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Precision', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_pre))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %% [markdown]
# **Time for Recall

# %%
new_metrics_rec = list(new_metrics['Recall'])
reported_rec = list(reported['Recall'])

display(reported)

#The Standard Deviations
new_metrics_rec_std = list(new_std['Recall_std'])
reported_rec_std = list(reported_std['Recall_std'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_rec))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
plt.bar(br1, new_metrics_rec, color = 'red', width = barWidth, edgecolor = 'black', label = 'Ours')
plt.errorbar(br1, new_metrics_rec, yerr=new_metrics_rec_std, fmt='none', capsize = 5, ecolor='black')


plt.bar(br2, reported_rec, color = 'green', width = barWidth, edgecolor = 'black', label = 'Omar et al')
plt.errorbar(br2, reported_rec, yerr=reported_rec_std, fmt='none', capsize = 5, ecolor='black')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Recall', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_rec))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
plt.show()
# Out:
#                     Model  Accuracy        F1    Recall  Precision       AUC
# 2  DecisionTreeClassifier  0.984764  0.948477  0.937746   0.955410  0.976052
# 4              GaussianNB  0.890412  0.669510  0.806377   0.596600  0.949075
# 0    KNeighborsClassifier  0.872179  0.433416  0.346095   0.594559  0.775290
# 1      LogisticRegression  0.857737  0.003390  0.001724   0.100000  0.804923
# 3  RandomForestClassifier  0.985682  0.949845  0.946755   0.957698  0.991222
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %% [markdown]
# **F1 is Next

# %%
new_metrics_f1 = list(new_metrics['F1'])
reported_f1 = list(reported['F1'])

#The Standard Deviations
new_metrics_f1_std = list(new_std['F1_std'])
reported_f1_std = list(reported_std['F1_std'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_f1))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
plt.bar(br1, new_metrics_f1, color = 'red', width = barWidth, edgecolor = 'black', label = 'Ours')
plt.errorbar(br1, new_metrics_f1, yerr=new_metrics_f1_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br2, reported_f1, color = 'green', width = barWidth, edgecolor = 'black', label = 'Omar et al')
plt.errorbar(br2, reported_f1, yerr=reported_f1_std, fmt='none', capsize = 5, ecolor='black')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('F1', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_f1))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]

# %% [markdown]
# **AUC should not be ignored

# %%
new_metrics_auc = list(new_metrics['AUC'])
reported_auc = list(reported['AUC'])

#The Standard Deviations
new_metrics_auc_std = list(new_std['AUC_std'])
reported_auc_std = list(reported_std['AUC_std'])

barWidth = 0.25
fig = plt.subplots(figsize = (10,6))

br1 = [x for x in np.arange(len(new_metrics_auc))]
print(br1)
br2 = [x + barWidth for x in br1]
print(br2)
plt.bar(br1, new_metrics_auc, color = 'red', width = barWidth, edgecolor = 'black', label = 'Ours')
plt.errorbar(br1, new_metrics_auc, yerr=new_metrics_auc_std, fmt='none', capsize = 5, ecolor='black')

plt.bar(br2, reported_auc, color = 'green', width = barWidth, edgecolor = 'black', label = 'Omar et al')
plt.errorbar(br2, reported_auc, yerr=reported_auc_std, fmt='none', capsize = 5, ecolor='black')

plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('AUC', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(new_metrics_f1))], ['Decision Tree', 'GNB', 'KNN', 'Logistic Regression', 'Random forest'])

plt.legend()
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]
